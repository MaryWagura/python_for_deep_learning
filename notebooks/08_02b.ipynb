# %%
# !pip install streamlit
# Out:
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import streamlit as st

st.write ("Hello World")
# Out:
# 2026-04-06 13:06:12.353 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-06 13:06:12.481
# ...
#   command:
#
#     streamlit run /home/clauds/anaconda3/lib/python3.13/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2026-04-06 13:06:12.482 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
