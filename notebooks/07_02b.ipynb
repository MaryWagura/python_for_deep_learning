# %% [markdown]
# ## Python requests for automating data collection.

# %%
import requests

# %%
response = requests.get('https://www.python.org')
response
# Out:
# <Response [200]>

# %% [markdown]
# ### Headers

# %%
response.headers
# Out:
# {'Connection': 'keep-alive', 'Content-Length': '49116', 'x-frame-options': 'SAMEORIGIN', 'content-type': 'text/html; charset=utf-8', 'via': '1.1 varnish, 1.1 varnish, 1.1 varnish', 'server': 'nginx', 'Accept-Ranges': 'bytes', 'Date': 'Sun, 29 Mar 2026 19:12:50 GMT', 'Age': '2851', 'X-Served-By': 'cache-iad-kiad7000081-IAD, cache-iad-kiad7000081-IAD, cache-cph2320052-CPH', 'X-Cache': 'MISS, HIT, HIT', 'X-Cache-Hits': '0, 580, 2', 'X-Timer': 'S1774811571.879698,VS0,VE0', 'Vary': 'Cookie', 'Strict-Transport-Security': 'max-age=63072000; includeSubDomains; preload'}

# %% [markdown]
# ### Content Types

# %% [markdown]
# ### Body/Content
