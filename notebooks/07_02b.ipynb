# %% [markdown]
# ## Python requests for automating data collection.

# %%
import requests

# %%
response = requests.get('https://www.python.org')
response
# Out:
# <Response [200]>

# %% [markdown]
# ### Headers

# %% [markdown]
# ### Content Types

# %% [markdown]
# ### Body/Content
